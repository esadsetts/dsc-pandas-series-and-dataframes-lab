# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# Rename all the columns to lower case
df = df.rename(str.lower, axis = 'columns')
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
#df = df.set_index('linename')
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df = df.reset_index()
df
# Out:
#          index    c/a  unit       scp        station linename division  \
# 0            0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1            1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2            2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3            3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4            4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...        ...    ...   ...       ...            ...      ...      ...
# 197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               date      time     desc  entries  \
# 0       08/25/2018  00:00:00  REGULAR  6736067
# 1       08/25/2018  04:00:00  REGULAR  6736087
# 2       08/25/2018  08:00:00  REGULAR  6736105
# 3       08/25/2018  12:00:00  REGULAR  6736180
# 4       08/25/2018  16:00:00  REGULAR  6736349
# ...            ...       ...      ...      ...
# 197620  08/31/2018  05:00:00  REGULAR     5554
# 197621  08/31/2018  09:00:00  REGULAR     5554
# 197622  08/31/2018  13:00:00  REGULAR     5554
# 197623  08/31/2018  17:00:00  REGULAR     5554
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 12 columns]

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
df['num_lines'] = df.linename.apply(lambda x : len(x)).sort_values(ascending = False)
df = df.sort_values(by = 'num_lines', ascending = False)
df
# Out:
#          index    c/a  unit       scp         station      linename division  \
# 132292  132292   R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686      2686   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673      2673   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674      2674   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675      2675   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...        ...    ...   ...       ...             ...           ...      ...
# 112565  112565  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112564  112564  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112563  112563  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112562  112562  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 197624  197624  TRAM2  R469  00-05-01   RIT-ROOSEVELT             R      RIT
#
#               date      time     desc  entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
# ...            ...       ...      ...      ...
# 112565  08/27/2018  09:28:23  REGULAR    28975
# 112564  08/27/2018  05:16:23  REGULAR    28319
# 112563  08/27/2018  01:04:23  REGULAR    28318
# 112562  08/26/2018  20:52:23  REGULAR    28305
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# ...                                                   ...
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         num_lines
# 132292         12
# 2686           12
# 2673           12
# 2674           12
# 2675           12
# ...           ...
# 112565          1
# 112564          1
# 112563          1
# 112562          1
# 197624          1
#
# [197625 rows x 13 columns]

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = col_name.title
    return cleaned

# %%
# Use the above function to clean the column names
df = df.rename(clean(str), axis = 'columns')

# %%
# Check to ensure the column names were cleaned
df.columns
df
# Out:
#          Index    C/A  Unit       Scp         Station      Linename Division  \
# 132292  132292   R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686      2686   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673      2673   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674      2674   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675      2675   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...        ...    ...   ...       ...             ...           ...      ...
# 112565  112565  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112564  112564  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112563  112563  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112562  112562  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 197624  197624  TRAM2  R469  00-05-01   RIT-ROOSEVELT             R      RIT
#
#               Date      Time     Desc  Entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
# ...            ...       ...      ...      ...
# 112565  08/27/2018  09:28:23  REGULAR    28975
# 112564  08/27/2018  05:16:23  REGULAR    28319
# 112563  08/27/2018  01:04:23  REGULAR    28318
# 112562  08/26/2018  20:52:23  REGULAR    28305
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         Exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# ...                                                   ...
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         Num_Lines
# 132292         12
# 2686           12
# 2673           12
# 2674           12
# 2675           12
# ...           ...
# 112565          1
# 112564          1
# 112563          1
# 112562          1
# 197624          1
#
# [197625 rows x 13 columns]

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
#df.Date = pd.to_datetime(df.Date)

# Add a new column 'day_of_week' that represents the day of the week 
#df['day_of_week'] = df.Date.apply(lambda x: x.day_name())
df
# Out:
#          Index    C/A  Unit       Scp         Station      Linename Division  \
# 132292  132292   R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686      2686   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673      2673   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674      2674   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675      2675   A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...        ...    ...   ...       ...             ...           ...      ...
# 112565  112565  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112564  112564  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112563  112563  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 112562  112562  PTH04  R551  00-04-05    GROVE STREET             1      PTH
# 197624  197624  TRAM2  R469  00-05-01   RIT-ROOSEVELT             R      RIT
#
#              Date      Time     Desc  Entries  \
# 132292 2018-08-30  00:00:00  REGULAR  1417952
# 2686   2018-08-29  16:00:00  REGULAR  2836145
# 2673   2018-08-27  16:00:00  REGULAR  2830710
# 2674   2018-08-27  20:00:00  REGULAR  2832048
# 2675   2018-08-28  00:00:00  REGULAR  2832325
# ...           ...       ...      ...      ...
# 112565 2018-08-27  09:28:23  REGULAR    28975
# 112564 2018-08-27  05:16:23  REGULAR    28319
# 112563 2018-08-27  01:04:23  REGULAR    28318
# 112562 2018-08-26  20:52:23  REGULAR    28305
# 197624 2018-08-31  21:00:00  REGULAR     5554
#
#         Exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# ...                                                   ...
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         Num_Lines day_of_week
# 132292         12    Thursday
# 2686           12   Wednesday
# 2673           12      Monday
# 2674           12      Monday
# 2675           12     Tuesday
# ...           ...         ...
# 112565          1      Monday
# 112564          1      Monday
# 112563          1      Monday
# 112562          1      Sunday
# 197624          1      Friday
#
# [197625 rows x 14 columns]

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
plt.show()
grouped
# Out:
#                   Index        Entries  \
# day_of_week
# Friday       2778112001  1110224700078
# Monday       2783610827  1114237052454
# Saturday     2741377942  1115661545514
# Sunday       2792287000  1192306179082
# Thursday     2817391725  1122723988662
# Tuesday      2833413973  1143313287046
# Wednesday    2781528032  1123655222441
#
#              Exits                                                                 \
# day_of_week
# Friday                                            906799065337
# Monday                                            911938153513
# Saturday                                          909142081474
# Sunday                                            959223750461
# Thursday                                          920691927110
# Tuesday                                           942230721477
# Wednesday                                         920630864687
#
#              Num_Lines
# day_of_week
# Friday           75573
# Monday           76110
# Saturday         74725
# Sunday           75306
# Thursday         76607
# Tuesday          77303
# Wednesday        75713

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
grouped = grouped.reset_index(drop = True)

# Print the first five rows of grouped
grouped.head()
# Out:
#         Index        Entries  \
# 0  2778112001  1110224700078
# 1  2783610827  1114237052454
# 2  2741377942  1115661545514
# 3  2792287000  1192306179082
# 4  2817391725  1122723988662
#
#    Exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    Num_Lines
# 0      75573
# 1      76110
# 2      74725
# 3      75306
# 4      76607

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped.index.map(weekend_map)
grouped
# Out:
#         Index        Entries  \
# 0  2778112001  1110224700078
# 1  2783610827  1114237052454
# 2  2741377942  1115661545514
# 3  2792287000  1192306179082
# 4  2817391725  1122723988662
# 5  2833413973  1143313287046
# 6  2781528032  1123655222441
#
#    Exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
# 5                                       942230721477
# 6                                       920630864687
#
#    Num_Lines is_weekend
# 0      75573      False
# 1      76110      False
# 2      74725      False
# 3      75306      False
# 4      76607      False
# 5      77303       True
# 6      75713       True

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
#wkend = wkend.rename(columns = {'Exits                                                               ' : 'Exits'})
#wkend.columns
wkend = grouped.groupby('is_weekend').mean()
wkend[['Entries']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop('C/A', axis = 1)
df = df.drop('Scp', axis = 1)
df.head(2)
# Out:
#          Index  Unit         Station      Linename Division       Date  \
# 132292  132292  R033  TIMES SQ-42 ST  1237ACENQRSW      IRT 2018-08-30
# 2686      2686  R032  TIMES SQ-42 ST  ACENQRS1237W      BMT 2018-08-29
#
#             Time     Desc  Entries  \
# 132292  00:00:00  REGULAR  1417952
# 2686    16:00:00  REGULAR  2836145
#
#         Exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
#
#         Num_Lines day_of_week
# 132292         12    Thursday
# 2686           12   Wednesday

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
